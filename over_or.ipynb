# %% [markdown]
# <a href="https://colab.research.google.com/github/jskroby/1/blob/main/over_or.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# STEP 2: Define installation directory in Google Drive
import os
OLLAMA_DIR = "/content/drive/MyDrive/ollama"
BIN_PATH = f"{OLLAMA_DIR}/bin"

# STEP 3: Create necessary directories
# !mkdir -p {BIN_PATH}

# STEP 4: Install Ollama (it will still install in /usr/local)
# !curl -fsSL https://ollama.com/install.sh | sh

# STEP 5: Move Ollama binary files to Drive (to persist)
# !mv /usr/local/bin/ollama {BIN_PATH}/ollama

# STEP 6: Fix permissions (Google Drive blocks execution by default)
# !chmod +x {BIN_PATH}/ollama

# STEP 7: Set environment variables correctly
os.environ["PATH"] += os.pathsep + BIN_PATH
os.environ["OLLAMA_DIR"] = OLLAMA_DIR
print(f"Ollama installed at: {OLLAMA_DIR}")

# STEP 8: Start Ollama Server (Manually)
# !{BIN_PATH}/ollama serve > /dev/null 2>&1 &
# !pip install ollama
# STEP 9: Verify Installation
# !{BIN_PATH}/ollama list
# !ollama pull mistral
# !curl http://127.0.0.1:11434/api/tags
import ollama
print(ollama.list())  # Check if Mistral is installed
import ollama
print(ollama.list())  # Check if models are detected!apt update
# !apt install -y pciutils lshw
# !lspci | grep -i nvidia
# !lshw -C display
# !nvcc --version
# !echo $PATH
# !pkill -f ollama  # Kill any running instance
# !{BIN_PATH}/ollama serve --use-gpu > /dev/null 2>&1 &  # Start server with GPU support
# !OLLAMA_USE_GPU=1 curl -fsSL https://ollama.com/install.sh | sh
# !OLLAMA_USE_GPU=1 ollama serve > /dev/null 2>&1 &
# !OLLAMA_USE_GPU=1 ollama serve &

# !ollama run mistral "infinite cartman in ascii 66 times in red and rainbow"
# Out:
# Mounted at /content/drive
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# #####                                                                                           6.1%
